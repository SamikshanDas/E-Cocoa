# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from skimage import io
from PIL import Image
import os
import numpy as np
import cv2
import pathlib

# %%
image_directory = 'imagebase/Small/'
dataset=[]
my_images = os.listdir(image_directory)
for i, image_name in enumerate(my_images):
    if (image_name.split('.')[1] == 'png'):
        image =io.imread(image_directory + image_name)
        #print(type(image))
        image = Image.fromarray(image)
        image = image.resize((200,200))
        dataset.append(np.array(image))
        
        

x = np.array(dataset)

# %%
datagen = ImageDataGenerator(
        rotation_range=45,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        fill_mode='constant',cval=200,
        )

# %%
i = 0
for batch in datagen.flow(x, batch_size=64,
                          save_to_dir='imagebase/Small',
                          save_prefix='aug', 
                          save_format='png'):
    i += 1
    if i >3:
        break

# %%
data_dir=pathlib.Path("imagebase")

# %%
small=list(data_dir.glob('Small/*'))
large=list(data_dir.glob('Large/*'))
medium=list(data_dir.glob('Medium/*'))
rejected=list(data_dir.glob('Rejected/*'))

# %%
Image.open(small[5])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=330x236 at 0x2958ECF48E0>

# %%
y=cv2.imread("imagebase/Large/aug_8_3010.png")

# %%
type(y)
# Out:
# numpy.ndarray

# %%
y.shape
# Out:
# (200, 200, 3)
